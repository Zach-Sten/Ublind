# %% [markdown]
# # Ublind — Demo Notebook
# Coming soon, 3D umaps and PCA visualizers.

# %%
# Import packages:
import ublind as ub
import scanpy as sc
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import Audio

# %% [markdown]
# # Embeddings to music!

# %%
# load in adata:
adata = sc.read_h5ad('example.h5ad')

# %%
# access the different instruments and cheatsheets using the helper functions:
ub.hlp.instruments()   # prints friendly table with aliases
ub.hlp.scales()        # prints scales with notes and vibes
ub.hlp.gm_table()      # full 128 GM instruments
ub.hlp.quickstart()    # usage cheat sheet
# Out:
# ╔══════════════════════════════════════════════╗
# ║         ublind — Available Instruments       ║
# ╠══════════════════════════════════════════════╣
# ║  Use with dim_inst_map={0: 'name', ...}     ║
# ╚══════════════════════════════════════════════╝
#
#   bass            →  Electric Bass (finger) (GM 33)
#   cello           →  Cello (GM 42)
#   clarinet        →  Clarinet (GM 71)
#   flute           →  Flute (GM 73)
#   guitar          →  Acoustic Guitar (steel) (GM 25)
#   harp            →  Orchestral Harp (GM 46)
#   horn            →  French Horn (GM 60)
#   piano           →  Acoustic Grand Piano (GM 0)
#   sax             →  Tenor Sax (GM 66)
#   strings         →  Violin (GM 40)
#   trombone        →  Trombone (GM 57)
#   trumpet         →  Trumpet (GM 56)
#   vibraphone      →  Vibraphone (GM 11)
#   viola           →  Viola (GM 41)
#   violin          →  Violin (GM 40)
#
#   Or pass any GM program number directly: {0: 42}
#   Full GM list: ub.hlp.gm_table()
# ╔══════════════════════════════════════════════╗
# ║           ublind — Available Scales          ║
# ╠══════════════════════════════════════════════╣
# ║  Use with scale='name' in preprocess()      ║
# ╚══════════════════════════════════════════════╝
#
#   chromatic       C C# D D# E F F# G G# A A# B  all 12 semitones, atonal chaos
#   major           C D E F G A B         happy, bright
#   minor           C D D# F G G# A#      sad, dark, dramatic
#   pentatonic      C D E G A             always sounds good, safe default
#   blues           C D# F F# G A#        jazzy, soulful
#   whole_tone      C D E F# G# A#        dreamy, floating, impressionist
#   dorian          C D D# F G A A#       jazzy minor, sophisticated
#   mixolydian      C D E F G A A#        bluesy major, laid back
#
#   Transpose with root=N  (0=C, 2=D, 4=E, 5=F, 7=G, 9=A, 11=B)
# ╔══════════════════════════════════════════════╗
# ║       General MIDI Instrument Table          ║
# ╠══════════════════════════════════════════════╣
# ║  Use with dim_inst_map={0: number, ...}     ║
# ╚══════════════════════════════════════════════╝
#
#     0  Acoustic Grand Piano
#     1  Bright Acoustic Piano
#     2  Electric Grand Piano
#     4  Electric Piano 1
#     5  Electric Piano 2
#     6  Harpsichord
#     8  Celesta
#     9  Glockenspiel
#    10  Music Box
#    11  Vibraphone
#    12  Marimba
#    13  Xylophone
#    14  Tubular Bells
#    24  Acoustic Guitar (nylon)
#    25  Acoustic Guitar (steel)
#    26  Electric Guitar (jazz)
#    27  Electric Guitar (clean)
#    32  Acoustic Bass
#    33  Electric Bass (finger)
#    40  Violin
#    41  Viola
#    42  Cello
#    43  Contrabass
#    46  Orchestral Harp
#    56  Trumpet
#    57  Trombone
#    60  French Horn
#    65  Alto Sax
#    66  Tenor Sax
#    71  Clarinet
#    73  Flute
#    74  Recorder
#    79  Ocarina
#
# ╔══════════════════════════════════════════════╗
# ║            ublind — Quick Start              ║
# ╚══════════════════════════════════════════════╝
#
#   import ublind as ub
#
#   ── Sweep mode (every dim = a voice) ──────────
#
#   ub.pp.preprocess(adata, embedding="X_umap",
#       time=10, scale="pentatonic",
#       dim_inst_map={0: "piano", 1: "cello"})
#   ub.tl.render(adata, "sweep.wav")
#   ub.pl.sweep(adata, color_by="cell_type")
#
#   ── Cluster mode (one cluster at a time) ──────
#
#   ub.pp.preprocess_clusters(adata,
#       cluster_key="cell_type", time=10,
#       order="largest", scale="pentatonic")
#   ub.tl.render(adata, "clusters.wav")
#   ub.pl.sweep_clusters(adata)
#
#   ── Spatial sweep (across tissue) ─────────────
#
#   ub.pp.preprocess_clusters(adata, ...)   # first
#   ub.pl.sweep_spatial(adata,
#       spatial_key="spatial", sweep_axis="both",
#       color_by="cell_type")
#
#   ── Interactive (click to hear) ───────────────
#
#   ub.pl.interactive(adata, color_by="cell_type")
#
#   ── Helpers ────────────────────────────────────
#
#   ub.hlp.scales()       # available scales
#   ub.hlp.instruments()  # available instruments
#   ub.hlp.gm_table()     # full GM instrument list

# %% [markdown]
# ## Listen across UMAP or your emebdding space of choice.

# %%
# What does it sound like as we sweep UMAP space?
ub.pp.compose(adata, embedding="X_umap", time=10, scale="pentatonic",
                 counterpoint = True, # This vaies the axis so that low notes on the 1st axis start of the left but low notes on the 2nd axis start at the top.
                 dim_inst_map={0: "piano", 1: "piano"}, subsample = 5000)
ub.tl.render(adata, "sweep.wav") # can change renderer to 'synth', 'midi', 'fluidsynth' but we highly recommend not using synth
Audio("sweep.wav")
# Out:
# ublind: preprocessed X_umap → 10000 notes, 2 voice(s) [Acoustic Grand Piano, Acoustic Grand Piano], 10.0s
# ublind: rendered → sweep.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# See what an orchestra of sounds sounds like across many dimensions in PC space! 
ub.pp.compose(adata, embedding="X_pca", time=10, scale="pentatonic", subsample = 5000)
ub.tl.render(adata, "sweep_pca.wav", renderer = 'synth') # can change renderer to 'synth', 'midi', 'fluidsynth'
Audio("sweep_pca.wav")

# %%
# Animated UMAP with audio... work in progress.
ub.pl.sweep(adata, color_by="Cell_Annotation_Mid", legend_loc="on data")
# Out:
# ublind: rendering animation frames...
# ublind: muxed audio into video
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# ## Listen by cluster:

# %%
# Optional play one cluster a time using various methods for organizing them.
ub.pp.compose_clusters(adata, embedding="X_umap", cluster_key="Cell_Annotation_Mid", counterpoint = False,
    time=10, order="largest", scale="pentatonic", subsample = 5000,
    dim_inst_map={0: "piano", 1: "cello"})
ub.tl.render(adata, "clusters.wav")
Audio("clusters.wav")
# Out:
# ublind: preprocessed X_umap → 910 notes, 25 clusters [largest], 2 voice(s) [Acoustic Grand Piano, Cello], 10.0s (0.40s/cluster)
# ublind: rendered → clusters.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Animated UMAP with audio... work in progress. no
ub.pl.sweep_clusters(adata, legend_loc="on data")
# Out:
# ublind: rendering cluster animation...
# ublind: muxed audio into video
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# ## If spatial coordinates are available, listen to your clusters across space:

# %%
# Sweep both axes simultaneously (piano left→right, cello bottom→top)
ub.pp.compose_clusters(adata, embedding="spatial", cluster_key="Cell_Annotation_Mid",
    time=10, order="alphabetical", scale="pentatonic",
    dim_inst_map={0: "piano", 1: "cello"})
ub.tl.render(adata, "clusters.wav")
# Out:
# ublind: preprocessed spatial → 1000 notes, 25 clusters [alphabetical], 2 voice(s) [Acoustic Grand Piano, Cello], 10.0s (0.40s/cluster)
# ublind: rendered → clusters.wav
# PosixPath('clusters.wav')

# %%
# Play by spatial position! 
ub.pl.sweep_spatial(adata, spatial_key="spatial", sweep_axis="both", subsample = None, # Better if you just keep the full structure.
                    color_by="Cell_Annotation_Mid", legend_loc="on data")
# Out:
# ublind: spatial sweep with 35955 points

# %% [markdown]
# ## Interact and create beautiful data compositions:
# Best to preprocess via *listen by cluster* before running

# %%
# need to fix to switch between embeddings. Subsampled if non spatial.
ub.pl.interactive(adata, color_by="Cell_Annotation_Mid", invert_y= False,
                  play_axis = 'both', counterpoint = True, embedding = 'X_umap')
# Out:
# <div id="ublind-interactive" style="display:inline-block; position:relative;">
#   <canvas id="ublind-canvas" width="700" height="700"
#     style="border:1px solid #ccc; cursor:crosshair;"></canvas>
#   <div id="ublind-info" style="
#     position:absolute; top:10px; right:10px; background:rgba(255,255,255,0.92);
#     padding:8px 12px; border-radius:6px; font:13px monospace; color:#000;
#     display:none; box-shadow:0 2px 8px rgba(0,0,0,0.15);
#   "></div>
#   <div style="text-align:center; margin-top:6px; font:12px sans-serif; color:#888;">
#     Click cluster to hear chord · Hover for notes · Scroll to zoom · Drag to pan · Double-click to reset
#   </div>
# </div>
#
# <script>
# (function() {
#   const points = [{"x": -8.001472473144531, "y": -10.942496299743652, "c": 3, "p0": 26, "p1": 98}, {"x": 3.676051139831543, "y": 1.6072368621826172, "c": 18, "p0": 81, "p1": 60}, {"x": -1.8624725341796875, "y": 0.37188148498535156, "c": 4, "p0": 55, "p1": 64}, {"x": -0.38219261169433594, "y": -0.5999832153320312, "c": 4, "p0": 62, "p1": 64}, {"x": -0.132080078125, "y": 6.256305694580078, "c": 14, "p0": 64, "p1": 45}, {"x": 1.6955842971801758, "y": 3.6894092559814453, "c": 18, "p0": 72, "p1": 52}, {"x": 0.9722414016723633, "y": 4.989282608032227, "c": 14, "p0": 69, "p1": 48}, {"x": -0.2330026626586914, "y": -2.328672409057617, "c": 4, "p0": 64, "p1": 72}, {"x": 0.19208145141601562, "y": 7.349806785583496, "c": 23, "p0": 64, "p1": 40}, {"x": 3.878997802734375, "y": -1.9561872482299805, "c": 11, "p0": 84, "p1": 72}, {"x": 0.7842292785644531, "y": -9.214937210083008, "c": 5, "p0": 69, "p1": 93}, {"x": -1.9896717071533203, "y": 6.591686248779297, "c": 24, "p0": 55, "p1": 43}, {"x": 6.5137939453125, "y": 7.271759986877441, "c": 7, "p0": 96, "p1": 40}, {"x": -1.2544021606445312, "y": -0.6923837661743164, "c": 4, "p0": 57, "p1": 67}, {"x": -1.6462020874023438, "y": 7.561495780944824, "c": 0, "p0": 57, "p1": 40}, {"x": -1.041128158569336, "y": 7.224575042724609, "c": 0, "p0": 60, "p1": 43}, {"x": 2.2416086196899414, "y