# %% [markdown]
# # ublind — Demo Notebook
# Coming soon! 3D UMAP integration and music

# %%
# Import packages:
import ublind as ub
import scanpy as sc
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import Audio

# %% [markdown]
# ## Scales & Instruments
#
# ### Scales
#
# Set `scale=` in `ub.pp.preprocess()`. Set `root=` to transpose (0=C, 2=D, 4=E, 5=F, 7=G, 9=A, 11=B).
#
# - `"pentatonic"` — C D E G A — always sounds good
# - `"major"` — happy, bright
# - `"minor"` — sad, dark
# - `"blues"` — jazzy, soulful
# - `"dorian"` — jazzy minor
# - `"mixolydian"` — bluesy major
# - `"whole_tone"` — dreamy, floating
# - `"chromatic"` — all 12 semitones, atonal
#
# ### Instruments
#
# Set `dim_inst_map=` in `ub.pp.preprocess()` — e.g. `{0: "piano", 1: "cello"}`.
#
# - `"piano"` — Acoustic Grand Piano (GM 0)
# - `"guitar"` — Acoustic Guitar (GM 25)
# - `"bass"` — Electric Bass (GM 33)
# - `"violin"` — Violin (GM 40)
# - `"viola"` — Viola (GM 41)
# - `"cello"` — Cello (GM 42)
# - `"harp"` — Orchestral Harp (GM 46)
# - `"trumpet"` — Trumpet (GM 56)
# - `"trombone"` — Trombone (GM 57)
# - `"horn"` — French Horn (GM 60)
# - `"sax"` — Tenor Sax (GM 66)
# - `"clarinet"` — Clarinet (GM 71)
# - `"flute"` — Flute (GM 73)
# - `"vibraphone"` — Vibraphone (GM 11)
#
# Or pass any GM program number directly: `{0: 42}` for Cello.

# %% [markdown]
# # Embeddings to music!

# %%
# load in adata:
adata = sc.read_h5ad('example.h5ad')

# %% [markdown]
# ## Listen across UMAP or your emebdding space of choice.

# %%
# Preprocess as you sweep across the UMAP
ub.pp.preprocess(adata, embedding="X_umap", time=10, scale="pentatonic",
    dim_inst_map={0: "piano", 1: "flute"}, subsample = 5000)
ub.tl.render(adata, "sweep.wav")
Audio("sweep.wav")
# Out:
# ublind: preprocessed X_umap → 10000 notes, 2 voice(s) [Acoustic Grand Piano, Flute], 10.0s
# ublind: rendered → sweep.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Animated UMAP with audio... work in progress.
ub.pl.sweep(adata, color_by="Cell_Annotation_Mid", legend_loc="on data")
# Out:
# ublind: rendering animation frames...
# ublind: muxed audio into video
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# ## Listen by cluster:

# %%
# Optional play one cluster a time using various methods for organizing them.
ub.pp.preprocess_clusters(adata, embedding="X_umap", cluster_key="Cell_Annotation_Mid",
    time=10, order="alphabetical", scale="pentatonic", subsample = 5000,
    dim_inst_map={0: "piano", 1: "cello"})
ub.tl.render(adata, "clusters.wav")
Audio("clusters.wav")
# Out:
# ublind: preprocessed X_umap → 910 notes, 25 clusters [alphabetical], 2 voice(s) [Acoustic Grand Piano, Cello], 10.0s (0.40s/cluster)
# ublind: rendered → clusters.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Animated UMAP with audio... work in progress. no
ub.pl.sweep_clusters(adata, legend_loc="on data")
# Out:
# ublind: rendering cluster animation...
# ublind: muxed audio into video
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# ## If spatial coordinates are available, listen to your clusters across space:

# %%
# Sweep both axes simultaneously (piano left→right, cello bottom→top)
ub.pp.preprocess_clusters(adata, embedding="X_umap", cluster_key="Cell_Annotation_Mid",
    time=10, order="alphabetical", scale="pentatonic",
    dim_inst_map={0: "piano", 1: "cello"})
ub.tl.render(adata, "clusters.wav")
# Out:
# ublind: preprocessed X_umap → 1000 notes, 25 clusters [alphabetical], 2 voice(s) [Acoustic Grand Piano, Cello], 10.0s (0.40s/cluster)
# ublind: rendered → clusters.wav
# PosixPath('clusters.wav')

# %%
# Play by spatial position! 
ub.pl.sweep_spatial(adata, spatial_key="spatial", sweep_axis="both", subsample = None, # Better if you just keep the full structure.
                    color_by="Cell_Annotation_Mid", legend_loc="on data")
# Out:
# ublind: spatial sweep with 5000 points
# ublind: rendering spatial animation...
# ublind: muxed audio into video
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# ## Interact and create beautiful data compositions:
# Best to preprocess via *listen by cluster* before running

# %%
ub.pl.interactive(adata, color_by="Cell_Annotation_Mid")
# Out:
# <div id="ublind-interactive" style="display:inline-block; position:relative;">
#   <canvas id="ublind-canvas" width="700" height="700"
#     style="border:1px solid #ccc; cursor:crosshair;"></canvas>
#   <div id="ublind-info" style="
#     position:absolute; top:10px; right:10px; background:rgba(255,255,255,0.92);
#     padding:8px 12px; border-radius:6px; font:13px monospace; color:#000;
#     display:none; box-shadow:0 2px 8px rgba(0,0,0,0.15);
#   "></div>
#   <div style="text-align:center; margin-top:6px; font:12px sans-serif; color:#888;">
#     Click cluster to hear chord · Hover for notes · Scroll to zoom · Drag to pan
#   </div>
# </div>
#
# <script>
# (function() {
# ...
